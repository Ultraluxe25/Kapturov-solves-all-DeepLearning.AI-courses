# %% [markdown]
# ### Форма ступенчатого ряда (или ступенчатая форма, row echelon form, REF) — это способ упрощения матрицы в линейной алгебре, который облегчает решение систем линейных уравнений.

# %% [markdown]
# ![image.png](attachment:cc65cead-e942-45ab-b68d-6ab5b826e60a.png)

# %% [markdown]
# ![image.png](attachment:360efc5d-b2fc-433a-a935-d13fe6e89e4d.png)
# ![image.png](attachment:e47cd704-3fbf-4499-b768-98f87641bde7.png)
# ![image.png](attachment:886b31e8-5d26-4f30-bd0e-55f86cf10cbd.png)
# ![image.png](attachment:8cf909ee-536f-4322-80af-c55b110d1980.png)
# ![image.png](attachment:9a22edb1-8a5d-44fc-aab7-0f0dbe5605cb.png)
# ![image.png](attachment:02dd5f5a-2d36-4e2c-a0cb-c435e098816e.png)
# ![image.png](attachment:199907a7-e3a3-4aa8-99a2-ada9a74ac93f.png)

# %% [markdown]
# ![image.png](attachment:05f0c56f-8dc8-4d83-9838-fcf70b9f4648.png)

# %% [markdown]
# ![image.png](attachment:3e8605c7-8beb-428c-adf7-7374141f6d9b.png)
# ![image.png](attachment:f5abddc0-3115-4fc7-a2ea-52b8cfc9fafb.png)
